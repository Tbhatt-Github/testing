# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 10, 100)
y = 2*np.linspace(5, 5000, 100)
plt.plot(x, y)
plt.grid()
plt.title("My First Plot on POP_OS!")
plt.show()

# %%
img = cv2.imread("../../Downloads/test_img.png")
cv2.imshow("image", img)
